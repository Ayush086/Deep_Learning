# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
or_data = pd.DataFrame()
and_data = pd.DataFrame()
xor_data = pd.DataFrame()

# %%
or_data['ip1'] = [1, 1, 0, 0]
or_data['ip2'] = [1, 0, 1, 0]
or_data['output'] = [1, 1, 1, 0]

# %%
and_data['ip1'] = [1, 1, 0, 0]
and_data['ip2'] = [1, 0, 1, 0]
and_data['output'] = [1, 0, 0, 0]

# %%
xor_data['ip1'] = [1, 1, 0, 0]
xor_data['ip2'] = [1, 0, 1, 0]
xor_data['output'] = [0, 1, 1, 0]

# %%
sns.scatterplot(x='ip1', y='ip2', hue='output', data=and_data, s=200)
# Out:
# <Axes: xlabel='ip1', ylabel='ip2'>

# %%
sns.scatterplot(x='ip1', y='ip2', hue='output', data=or_data, s=200)
# Out:
# <Axes: xlabel='ip1', ylabel='ip2'>

# %%
sns.scatterplot(x='ip1', y='ip2', hue='output', data=xor_data, s=200)
# Out:
# <Axes: xlabel='ip1', ylabel='ip2'>

# %%
from sklearn.linear_model import Perceptron

clf1 = Perceptron()
clf2 = Perceptron()
clf3 = Perceptron()

# %%
clf1.fit(and_data.iloc[:, 0:2].values, and_data.iloc[:, -1].values)
clf2.fit(or_data.iloc[:, 0:2].values, or_data.iloc[:, -1].values)
clf3.fit(xor_data.iloc[:, 0:2].values, xor_data.iloc[:, -1].values)
# Out:
# Perceptron()

# %%
clf1.coef_
# Out:
# array([[2., 2.]])

# %%
clf1.intercept_
# Out:
# array([-2.])

# %%
x = np.linspace(-1, 1, 5)
y = -x + 1

# %%
plt.plot(x, y)
sns.scatterplot(x='ip1', y='ip2', hue='output', data=and_data, s=200)
# Out:
# <Axes: xlabel='ip1', ylabel='ip2'>

# %%
clf2.coef_
# Out:
# array([[2., 2.]])

# %%
clf2.intercept_
# Out:
# array([-1.])

# %%
x1 = np.linspace(-1, 1, 5)
y1 = -x + 0.5

# %%
plt.plot(x1, y1)
sns.scatterplot(x='ip1', y='ip2', hue='output', data=or_data, s=200)
# Out:
# <Axes: xlabel='ip1', ylabel='ip2'>

# %%
clf3.coef_
# Out:
# array([[0., 0.]])

# %%
clf3.intercept_
# Out:
# array([0.])

# %%
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(xor_data.iloc[:, 0:2].values, xor_data.iloc[:, -1].values, clf=clf3, legend=2)
# Out:
# <Axes: >

# %% [markdown]
# NO clear boundary formed.
